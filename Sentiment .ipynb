# %%
pip install textblob
# Out:
# Requirement already satisfied: textblob in /opt/conda/lib/python3.10/site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /opt/conda/lib/python3.10/site-packages (from textblob) (3.8.1)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk>=3.1->textblob) (2023.8.8)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk>=3.1->textblob) (8.1.4)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk>=3.1->textblob) (1.3.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from nltk>=3.1->textblob) (4.65.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from textblob import TextBlob

# %%
sample_texts = [
    "I love programming.",
    "I hate bugs.",
    "I feel indifferent about documentation.",
    "Debugging is fun!",
    "I'm frustrated with errors."
]

# %%
for text in sample_texts:
    analysis = TextBlob(text)
    polarity = analysis.sentiment.polarity
    subjectivity = analysis.sentiment.subjectivity
    
    if polarity > 0:
        sentiment = "Positive"
    elif polarity < 0:
        sentiment = "Negative"
    else:
        sentiment = "Neutral"
    
    print(f"Text: {text}")
    print(f"Sentiment: {sentiment}")
    print(f"Polarity: {polarity}")
    print(f"Subjectivity: {subjectivity}")
    print("------")
# Out:
# Text: I love programming.
# Sentiment: Positive
# Polarity: 0.5
# Subjectivity: 0.6
# ------
# Text: I hate bugs.
# Sentiment: Negative
# Polarity: -0.8
# Subjectivity: 0.9
# ------
# Text: I feel indifferent about documentation.
# Sentiment: Neutral
# Polarity: 0.0
# Subjectivity: 0.0
# ------
# Text: Debugging is fun!
# Sentiment: Positive
# Polarity: 0.375
# Subjectivity: 0.2
# ------
# Text: I'm frustrated with errors.
# Sentiment: Negative
# Polarity: -0.7
# Subjectivity: 0.2
# ------
